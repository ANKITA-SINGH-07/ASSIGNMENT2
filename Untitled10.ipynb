# %%
# Importing required libraries.
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %%
survey_result_schema=pd.read_csv("survey_results_schema.csv")

# %%
survey_result_public=pd.read_csv("survey_results_public.csv",error_bad_lines=False)

# %%
survey_result_public.head()
# Out:
#    Respondent  ...                  SurveyEase
# 0           1  ...  Neither easy nor difficult
# 1           2  ...  Neither easy nor difficult
# 2           3  ...  Neither easy nor difficult
# 3           4  ...                        Easy
# 4           5  ...                        Easy
#
# [5 rows x 85 columns]

# %% [markdown]
# FIND AVERAGE AGE OF DEVELOPERS WHEN THEY WROTE THEIR FRST LINE OF CODE

# %%
survey_result_public
# Out:
#       Respondent  ...                  SurveyEase
# 0              1  ...  Neither easy nor difficult
# 1              2  ...  Neither easy nor difficult
# 2              3  ...  Neither easy nor difficult
# 3              4  ...                        Easy
# 4              5  ...                        Easy
# ...          ...  ...                         ...
# 1419        1426  ...                        Easy
# 1420        1427  ...                        Easy
# 1421        1428  ...                        Easy
# 1422        1429  ...                        Easy
# 1423        1430  ...                         NaN
#
# [1424 rows x 85 columns]

# %%
survey_result_public['Age1stCode'] = pd.to_numeric(survey_result_public.Age1stCode, errors='coerce')

# %%
 survey_result_public['Age1stCode'].mean()
# Out:
# 15.476973496179715
